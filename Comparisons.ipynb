# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [588.248816, 469.139247, 462.898014, 564.776899, 948.578531, 1650.005449, 2759.128531, 6007.771463, 9685.300044, 33806.4501]
radix_sort_time = [540.312809, 354.140161, 362.068999, 440.177208, 816.42344, 1429.436707, 2617.69906, 1908.003966, 7272.337938, 22028.45324]
merge_sort_time = [189.692341, 297.838364, 525.915416, 997.046514, 1962.252925, 3960.292893, 8028.863412, 16429.24231, 34017.0199, 69459.53015]  # None for missing value
bitonic_sort_time = [1973.642463, 3779.98994, 7417.477887, 14660.39249, 29215.74087, 58224.5827, 116241.4208, 232025.0996, 462439.2425, None]  # Adjusted to match

# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title
plt.xlabel('Number of Processors')
plt.ylabel('Time (seconds)')
plt.title('Total Time vs. Number of Processors (Random 268435456)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

sample_sort_time = [0.725012, 1.647564, 3.863668, 12.700108, 51.201977, 97.772812, 211.332729, 463.87285, 951.375638, 4085.806112]
radix_sort_time = [1.329406, 2.372741, 5.505953, 12.446411, 51.587322, 132.368598, 391.702651, 735.886975, 1126.240041, 2474.993063]
merge_sort_time = [0.631784, 1.488883, 3.997284, 12.411148, 27.993789, 52.607299, 116.6761, 516.825453, 623.660441, 1776.886718]
bitonic_sort_time = [1.240966, 1.872829, 4.846107, 15.090622, 53.398146, 168.151958, 345.739764, 486.590299, 1166.455794, None]

# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title
plt.xlabel('Number of Processors')
plt.ylabel('Time (seconds)')
plt.title('Total Time vs. Number of Processors (Random 65536)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [1, 2.507701, 5.083168, 8.332344, 9.920717, 11.406475, 13.639794, 12.529371, 15.51861, 8.888372]
radix_sort_time = [1, 3.051406596, 5.969169523, 9.819914525, 10.58887382, 12.09568041, 13.21008217, 36.2473273, 19.02002917, 12.55831085]
merge_sort_time = [1, 1.273797, 1.442714, 1.522002, 1.546684, 1.53264, 1.511965, 1.477745, 1.426602, 1.397628]
bitonic_sort_time = [1, 1.044258, 1.064319, 1.076993, 1.080861, 1.084695, 1.086636, 1.088432, 1.092531, None]


# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title

plt.xlabel('Number of Processors')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Processors (Random 268435456)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [6.004673, 3.832808, 2.132677, 1.710867, 1.290797, 1.172404, 1.04354, 1.071404, 1.209476, 2.157304]
radix_sort_time = [46.312956, 26.404763, 20.32046, 15.308864, 16.536309, 15.951953, 14.922937, 1.920582, 7.937566, 15.201419]
merge_sort_time = [0.828238, 0.811867, 0.854385, 0.853208, 0.780032, 0.579991, 0.538041, 0.541174, 0.68031, 0.953346]
bitonic_sort_time = [1.070903, 1.105977, 1.222151, 1.297471, 1.405632, 1.213485, 1.113906, 1.084825, 1.049618, None]



# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title

plt.xlabel('Number of Processors')
plt.ylabel('Max/Time Rank (seconds)')
plt.title('Comm vs. Number of Processors (1%_Perturbed 268435456)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [0.015363, 0.019535, 0.025011, 0.029213, 0.064902, 0.025386, 0.06816, 0.068527, 0.201986, 0.382659]
radix_sort_time = [0.064948, 0.044599, 0.043258, 0.041955, 0.072638, 0.048968, 1.05733, 0.072551, 0.32974, 0.303265]
merge_sort_time = [0.017022, 0.012753, 0.023779, 0.028534, 0.048166, 0.057088, 0.059426, 0.114317, 0.159444, 0.309704]
bitonic_sort_time = [0.001763, 0.001677, 0.006704, 0.003555, 0.048046, 0.014004, 0.054603, 1.014943, 0.136917, None]


# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title

plt.xlabel('Number of Processors')
plt.ylabel('Max/Time Rank (seconds)')
plt.title('Comm vs. Number of Processors (1%_Perturbed 65536)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [275.686266, 109.851935, 36.644851, 31.442342, 24.134002, 16.99534, 17.689947, 19.726166, 21.626861, 31.47115]
radix_sort_time = [232.162797, 71.206252, 33.952614, 18.445705, 16.298337, 14.347101, 13.111675, 0.985496, 6.417552, 12.769583]
merge_sort_time = [64.485832, 53.565867, 48.381229, 45.632824, 44.45821, 43.968889, 43.491034, 43.352585, 43.398703, 43.516029]
bitonic_sort_time = [892.703524, 892.160581, 891.589647, 891.495288, 891.786465, 890.604291, 890.359398, 889.40241, 888.188954, None]

# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title
plt.xlabel('Number of Processors')
plt.ylabel('Max Time/Rank (seconds)')
plt.title('Comp Large vs. Number of Processors (Sorted 268435456)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [282.537848, 110.142808, 53.338487, 31.848976, 25.660966, 22.326824, 18.310409, 20.044928, 15.589649, 26.447686]
radix_sort_time = [235.877046, 72.89544, 34.354796, 18.745391, 16.495495, 14.435556, 13.162421, 1.033484, 6.625399, 12.757314]
merge_sort_time = [87.192155, 66.765193, 57.884465, 54.13891, 53.321391, 53.785198, 54.576696, 55.877619, 57.275378, 59.062836]
bitonic_sort_time = [903.899054, 902.534195, 903.522935, 901.8524, 902.346896, 901.37681, 900.107867, 898.216683, 896.516449, None]

# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title
plt.xlabel('Number of Processors')
plt.ylabel('Max Time/Rank (seconds)')
plt.title('Comp Large vs. Number of Processors (Random 268435456)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
processors = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
sample_sort_time = [1, 0.874038, 0.750498, 0.456027, 0.225771, 0.236312, 0.218466, 0.198953, 0.191387, 0.08917]
radix_sort_time = [1, 1.120566097, 0.9657955609, 0.8544827684, 0.4123201729, 0.3213828636, 0.2172106385, 0.2312365936, 0.302180582, 0.2750132914]
merge_sort_time = [1, 0.85, 0.6318, 0.4075, 0.3604, 0.3841, 0.3451, 0.1563, 0.2519, 0.1782]
bitonic_sort_time = [1, 1.32585, 1.024701, 0.657425, 0.371167, 0.235885, 0.229, 0.318375, 0.267246, None]

# Convert processors to log scale for equal spacing
log_processors = np.log2(processors)

# Plotting each sorting algorithm using log-scaled processors on a linear axis for equal spacing
plt.figure(figsize=(10, 6))

plt.plot(log_processors, sample_sort_time, marker='o', label='Sample Sort')
plt.plot(log_processors, radix_sort_time, marker='o', label='Radix Sort')
plt.plot(log_processors, merge_sort_time, marker='o', label='Merge Sort')
plt.plot(log_processors, bitonic_sort_time, marker='o', label='Bitonic Sort')

# Adding labels and title
plt.xlabel('Number of Processors')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Processors (Random 65536)')
plt.legend()
plt.grid(True, which="both")

# Set custom x-ticks with actual processor values
plt.xticks(log_processors, processors)

# Show plot
plt.show()
